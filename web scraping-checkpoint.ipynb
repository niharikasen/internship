# %%
# !pip install bs4
# !pip install requests

# %%
from bs4 import BeautifulSoup
import requests
import pandas as pd

# %%
url= requests.get('https://en.wikipedia.org/wiki/Main_Page')

# %%
url
# Out:
# <Response [200]>

# %%
soup = BeautifulSoup(url.content)
soup
# Out:
# <!DOCTYPE html>
# <html class="client-nojs vector-feature-language-in-header-enabled vector-feature-language-in-main-page-header-disabled vector-feature-sticky-header-disabled vector-feature-page-tools-pinned-disabled vector-feature-toc-pinned-clientpref-1 vector-feature-main-menu-pinned-disabled vector-feature-limited-width-clientpref-1 vector-feature-limited-width-content-enabled vector-feature-custom-font-size-clientpref-0 vector-feature-client-preferences-disabled vector-feature-client-prefs-pinned-disabled vector-toc-not-available" dir="ltr" lang="en">
# <head>
# <meta charset="utf-8"/>
# <title>Wikipedia, the free encyclopedia</title>
# ...

# %%
header_tags= soup.find_all(["h1","h2","h3","h4","h5","h6"])

# %%
header_texts=[tag.get_text()for tag in header_tags]

# %%
df= pd.DataFrame(header_texts,columns=["Header"])
print(df)
# Out:
#                           Header
# 0                      Main Page
# 1           Welcome to Wikipedia
# 2  From today's featured article
# 3               Did you know ...
# 4                    In the news
# 5                    On this day
# 6       Today's featured picture
# 7       Other areas of Wikipedia
# 8    Wikipedia's sister projects
# 9            Wikipedia languages

# %%
url = requests.get('https://www.cnbc.com/world/?region=world')

# %%
url
# Out:
# <Response [200]>

# %%
soup = BeautifulSoup(url.content)

# %%
soup
# Out:
# <!DOCTYPE html>
# ...

# %%
articles  = soup.find_all('div', class_= "LatestNews-headlineWrapper")
articles
# Out:
# []

# %%
titles =soup.find('h2', class_="FeaturedCard-packagedCardTitle")
titles

# %%
link =soup.find_all('a', href ="https://www.cnbc.com/2024/01/29/chinas-luxury-market-is-bouncing-back-with-new-areas-of-opportunity.html" )
link
# Out:
# []

# %%
#create dataframe
data = ({"Headline":headlines,"Time":times,"News Link":link})
df= pd.DataFrame(data)
print(df)
# Out:
# Empty DataFrame
# Columns: [Headline, Time, News Link]
# Index: []

# %%
 url = requests.get('https://www.journals.elsevier.com/artificial-intelligence/most-downloaded-articles')

# %%
url
# Out:
# <Response [200]>

# %%
soup = BeautifulSoup(url.content)

# %%
soup
# Out:
# <!DOCTYPE html>
# ...

# %%
titles = soup.find('h2', class_= "sc-1qrq3sd-1 gRGSUS sc-1nmom32-0 sc-1nmom32-1 btcbYu goSKRg")
titles.text
# Out:
# 'Reward is enough'

# %%
authors =[] 
for i in soup.find_all("span" ,class_="button-link-text"):
    authors.append(i, text)
authors
# Out:
# []

# %%
date= soup.find_all('p', class_="text-s")
date
# Out:
# []

# %%
url =soup.find_all('span', class_="anchor-text")
url
# Out:
# []

# %%
df=pd.DataFrame({"Paper Title":titles,"Authors":authors,"Date":date,"Paper url":urls})
print(df)
# Out:
# Empty DataFrame
# Columns: [Paper Title, Authors, Date, Paper url]
# Index: []

# %%
url =requests.get('https://www.dineout.co.in/delhi-restaurants/buffet-special'

# %%
url
# Out:
# <Response [200]>

# %%
soup =BeautifulSoup(url.content)

# %%
soup
# Out:
# <!DOCTYPE html>
# <html lang="en"><head><meta charset="utf-8"/><meta content="IE=edge" http-equiv="X-UA-Compatible"/><meta content="width=device-width, initial-scale=1.0, maximum-scale=1.0, user-scalable=no" name="viewport"/><link href="/manifest.json" rel="manifest"/><style type="text/css">
#             @font-face {
#                 font-family: 'dineicon';
#                 src:  url('/fonts/dineicon.eot');
#                 src:  url('/fonts/dineicon.eot#iefix') format('embedded-opentype'),
#                 url('/fonts/dineicon.ttf') format('truetype'),
#                 url('/fonts/dineicon.woff') format('woff'),
#                 url('/fonts/dineicon.svg#dineicon') format('svg');
#                 font-weight: normal;
# 				font-style: normal;
# 				font-display: swap;
#             }
#             .hide {
#                 display: none !important;
#             }
#             .async-hide{
#                 opacity: inherit !important;
#             }
# ...

# %%
first_title= soup.find('div',class_="restnt-info cursor")
first_title.text
# Out:
# 'Castle BarbequeConnaught Place, Central Delhi'

# %%
location =soup.find('div',class_="restnt-loc ellipsis")
location.text
# Out:
# 'Connaught Place, Central Delhi'

# %%
rating= soup.find('div',class_="restnt-rating rating-4")
rating.text
# Out:
# '4'

# %%
images= []
for i in  soup.find_all("img",class_="no-img"):
        
    images.append(i['data-src'])
    images

# %%
import pandas as pd

# %%
print(len(titles),len(location),len(rating),len(images))
# Out:
# 0 3 1 7

# %%
df= pd.DataFrame({'Titles':title, 
                  'Location':location,
                  'Rating':rating,
                  'Images':images})

print(df)
# Out:
# Empty DataFrame
# Columns: [Titles, Location, Rating, Images]
# Index: []
